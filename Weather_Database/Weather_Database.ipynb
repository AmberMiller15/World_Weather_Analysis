# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low = -90.000, high = 90.000, size = 2000)
lngs = np.random.uniform(low = -180.000, high = 180.000, size = 2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = []

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 727

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=' + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + '&q=' + city.replace (' ', '+')
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        
        # Parse the JSON and retrieve the data.
        city_weather = requests.get(city_url).json()

        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_current = city_weather['weather'][0]['description']


        # Append the city information into the city_data list
        city_data.append({'City' : city.title(),
                          'Lat' : city_lat,
                          'Lng' : city_lng,
                          'Max Temp' : city_max_temp,
                          'Humidity' : city_humidity,
                          'Cloudiness' : city_clouds,
                          'Wind Speed' : city_wind,
                          'Country' : city_country,
                          'Current Description': city_current})
        
    
    # If an error is experienced, skip the city
    except:
        print ('City not found. Skipping...')
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sur
# Processing Record 2 of Set 1 | severo-kurilsk
# Processing Record 3 of Set 1 | carnarvon
# Processing Record 4 of Set 1 | balkhash
# Processing Record 5 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 6 of Set 1 | punta arenas
# Processing Record 7 of Set 1 | dekar
# Processing Record 8 of Set 1 | bredasdorp
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | mataura
# Processing Record 11 of Set 1 | ust-nera
# Processing Record 12 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 1 | hasaki
# Processing Record 14 of Set 1 | tucuman
# Processing Record 15 of Set 1 | qaanaaq
# Processing Record 16 of Set 1 | batemans bay
# Processing Record 17 of Set 1 | rikitea
# Processing Record 18 of Set 1 | sitka
# Processing Record 19 of Set 1 | laguna
# Processing Record 20 of Set 1 | rawson
# Processing Record 21 of Set 1 | tucurui
# Processing Record 22 of Set 1 | busselton
# Processing Record 23 of Set 1 | pamanukan
# Processing Record 24 of Set 1 | margate
# Processing Record 25 of Set 1 | kapaa
# Processing Record 26 of Set 1 | hermanus
# Processing Record 27 of Set 1 | iquitos
# Processing Record 28 of Set 1 | guangshui
# Processing Record 29 of Set 1 | kupang
# Processing Record 30 of Set 1 | kruisfontein
# Processing Record 31 of Set 1 | clarksdale
# Processing Record 32 of Set 1 | khatanga
# Processing Record 33 of Set 1 | bowen
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | ostrovnoy
# Processing Record 36 of Set 1 | chuy
# Processing Record 37 of Set 1 | norman wells
# Processing Record 38 of Set 1 | sibolga
# Processing Record 39 of Set 1 | thompson
# Processing Record 40 of Set 1 | wanning
# Processing Record 41 of Set 1 | ji-parana
# City not found. Skipping...
# Processing Record 42 of Set 1 | fare
# Processing Record 43 of Set 1 | mandalgovi
# Processing Record 44 of Set 1 | taburi
# City not found. Skipping...
# Processing Record 45 of Set 1 | galdar
# Processing Record 46 of Set 1 | hithadhoo
# Processing Record 47 of Set 1 | nantucket
# Processing Record 48 of Set 1 | tuktoyaktuk
# Processing Record 49 of Set 1 | kaeng khoi
# Processing Record 50 of Set 1 | saint-augustin
# Processing Record 1 of Set 2 | hobyo
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | pedro juan caballero
# Processing Record 4 of Set 2 | mahebourg
# Processing Record 5 of Set 2 | kulu
# Processing Record 6 of Set 2 | isangel
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | provideniya
# Processing Record 9 of Set 2 | tazmalt
# Processing Record 10 of Set 2 | jamestown
# Processing Record 11 of Set 2 | oni
# Processing Record 12 of Set 2 | sao filipe
# Processing Record 13 of Set 2 | coahuayana
# Processing Record 14 of Set 2 | vaini
# Processing Record 15 of Set 2 | zwedru
# Processing Record 16 of Set 2 | berlevag
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | tual
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | pafos
# Processing Record 21 of Set 2 | east london
# Processing Record 22 of Set 2 | ahipara
# Processing Record 23 of Set 2 | albany
# Processing Record 24 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 25 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 26 of Set 2 | saskylakh
# Processing Record 27 of Set 2 | hervey bay
# Processing Record 28 of Set 2 | santa clarita
# Processing Record 29 of Set 2 | bendigo
# Processing Record 30 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 31 of Set 2 | neiafu
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | dospat
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | codrington
# Processing Record 36 of Set 2 | boende
# Processing Record 37 of Set 2 | marsh harbour
# Processing Record 38 of Set 2 | qaqortoq
# Processing Record 39 of Set 2 | bokspits
# City not found. Skipping...
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | castro
# Processing Record 42 of Set 2 | kahului
# Processing Record 43 of Set 2 | vila franca do campo
# Processing Record 44 of Set 2 | vao
# Processing Record 45 of Set 2 | amalapuram
# Processing Record 46 of Set 2 | pokosnoye
# Processing Record 47 of Set 2 | dikson
# Processing Record 48 of Set 2 | barrow
# Processing Record 49 of Set 2 | broome
# Processing Record 50 of Set 2 | port alfred
# Processing Record 1 of Set 3 | bethel
# Processing Record 2 of Set 3 | port lincoln
# Processing Record 3 of Set 3 | cherskiy
# Processing Record 4 of Set 3 | mar del plata
# Processing Record 5 of Set 3 | ngunguru
# Processing Record 6 of Set 3 | cayenne
# Processing Record 7 of Set 3 | coquimbo
# Processing Record 8 of Set 3 | beringovskiy
# Processing Record 9 of Set 3 | port elizabeth
# Processing Record 10 of Set 3 | panaba
# Processing Record 11 of Set 3 | yanji
# Processing Record 12 of Set 3 | cidreira
# Processing Record 13 of Set 3 | arman
# Processing Record 14 of Set 3 | cabo san lucas
# Processing Record 15 of Set 3 | sidi ali
# Processing Record 16 of Set 3 | uri
# Processing Record 17 of Set 3 | camacha
# Processing Record 18 of Set 3 | tasiilaq
# Processing Record 19 of Set 3 | ancud
# Processing Record 20 of Set 3 | princeton
# Processing Record 21 of Set 3 | cabedelo
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | devils lake
# Processing Record 24 of Set 3 | aitape
# Processing Record 25 of Set 3 | buluang
# Processing Record 26 of Set 3 | pisco
# Processing Record 27 of Set 3 | ambilobe
# Processing Record 28 of Set 3 | ilulissat
# Processing Record 29 of Set 3 | fortuna
# Processing Record 30 of Set 3 | guerrero negro
# Processing Record 31 of Set 3 | yertsevo
# Processing Record 32 of Set 3 | japura
# Processing Record 33 of Set 3 | narsaq
# Processing Record 34 of Set 3 | adrar
# Processing Record 35 of Set 3 | nikolskoye
# Processing Record 36 of Set 3 | llanes
# Processing Record 37 of Set 3 | alofi
# Processing Record 38 of Set 3 | tambacounda
# Processing Record 39 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 40 of Set 3 | lagoa
# Processing Record 41 of Set 3 | taraz
# Processing Record 42 of Set 3 | naze
# Processing Record 43 of Set 3 | airai
# Processing Record 44 of Set 3 | rafaela
# Processing Record 45 of Set 3 | yellowknife
# Processing Record 46 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 47 of Set 3 | constitucion
# Processing Record 48 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 49 of Set 3 | chapais
# Processing Record 50 of Set 3 | alihe
# Processing Record 1 of Set 4 | andros town
# Processing Record 2 of Set 4 | rozkishne
# Processing Record 3 of Set 4 | poum
# Processing Record 4 of Set 4 | lavrentiya
# Processing Record 5 of Set 4 | emerald
# Processing Record 6 of Set 4 | broken hill
# Processing Record 7 of Set 4 | bluff
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | fairbanks
# Processing Record 10 of Set 4 | larsnes
# Processing Record 11 of Set 4 | vardo
# Processing Record 12 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 4 | carutapera
# Processing Record 14 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 15 of Set 4 | arlit
# Processing Record 16 of Set 4 | gornyy
# Processing Record 17 of Set 4 | dongying
# Processing Record 18 of Set 4 | xining
# Processing Record 19 of Set 4 | torbay
# Processing Record 20 of Set 4 | cam pha
# City not found. Skipping...
# Processing Record 21 of Set 4 | benguela
# Processing Record 22 of Set 4 | vostok
# Processing Record 23 of Set 4 | manoharpur
# Processing Record 24 of Set 4 | saint-philippe
# Processing Record 25 of Set 4 | uige
# Processing Record 26 of Set 4 | bambous virieux
# Processing Record 27 of Set 4 | hazorasp
# Processing Record 28 of Set 4 | araouane
# Processing Record 29 of Set 4 | clyde river
# Processing Record 30 of Set 4 | bilma
# Processing Record 31 of Set 4 | kodiak
# Processing Record 32 of Set 4 | nome
# Processing Record 33 of Set 4 | butaritari
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | pangai
# Processing Record 36 of Set 4 | sobolevo
# Processing Record 37 of Set 4 | pushkinskiye gory
# Processing Record 38 of Set 4 | vrises
# Processing Record 39 of Set 4 | faanui
# Processing Record 40 of Set 4 | lompoc
# Processing Record 41 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 42 of Set 4 | hilo
# Processing Record 43 of Set 4 | saint-francois
# Processing Record 44 of Set 4 | nagato
# Processing Record 45 of Set 4 | korla
# Processing Record 46 of Set 4 | birao
# Processing Record 47 of Set 4 | ribeira grande
# Processing Record 48 of Set 4 | mount isa
# Processing Record 49 of Set 4 | iqaluit
# Processing Record 50 of Set 4 | hofn
# Processing Record 1 of Set 5 | kutum
# Processing Record 2 of Set 5 | shizuishan
# Processing Record 3 of Set 5 | moa
# Processing Record 4 of Set 5 | bonoua
# Processing Record 5 of Set 5 | plymouth
# Processing Record 6 of Set 5 | tuatapere
# Processing Record 7 of Set 5 | san patricio
# Processing Record 8 of Set 5 | haines junction
# Processing Record 9 of Set 5 | touros
# Processing Record 10 of Set 5 | ulladulla
# Processing Record 11 of Set 5 | ambulu
# Processing Record 12 of Set 5 | honolulu
# Processing Record 13 of Set 5 | tieling
# Processing Record 14 of Set 5 | komarikhinskiy
# Processing Record 15 of Set 5 | temaraia
# City not found. Skipping...
# Processing Record 16 of Set 5 | mana
# Processing Record 17 of Set 5 | bjornevatn
# Processing Record 18 of Set 5 | kilgore
# Processing Record 19 of Set 5 | tiksi
# Processing Record 20 of Set 5 | saldanha
# Processing Record 21 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 22 of Set 5 | paita
# Processing Record 23 of Set 5 | meulaboh
# Processing Record 24 of Set 5 | nador
# Processing Record 25 of Set 5 | sorland
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | namibe
# Processing Record 28 of Set 5 | soyo
# Processing Record 29 of Set 5 | akcakoca
# Processing Record 30 of Set 5 | chokurdakh
# Processing Record 31 of Set 5 | gat
# Processing Record 32 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 33 of Set 5 | vanimo
# Processing Record 34 of Set 5 | safwah
# City not found. Skipping...
# Processing Record 35 of Set 5 | sambava
# Processing Record 36 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 37 of Set 5 | bagdarin
# Processing Record 38 of Set 5 | kroya
# Processing Record 39 of Set 5 | selishche
# Processing Record 40 of Set 5 | egvekinot
# Processing Record 41 of Set 5 | puerto ayora
# Processing Record 42 of Set 5 | victoria
# Processing Record 43 of Set 5 | zaria
# Processing Record 44 of Set 5 | nishihara
# Processing Record 45 of Set 5 | bemidji
# Processing Record 46 of Set 5 | kidal
# Processing Record 47 of Set 5 | comodoro rivadavia
# Processing Record 48 of Set 5 | craig
# Processing Record 49 of Set 5 | esperance
# Processing Record 50 of Set 5 | vinh
# Processing Record 1 of Set 6 | sao geraldo do araguaia
# Processing Record 2 of Set 6 | tateyama
# Processing Record 3 of Set 6 | buraydah
# Processing Record 4 of Set 6 | yeppoon
# Processing Record 5 of Set 6 | auki
# Processing Record 6 of Set 6 | goderich
# Processing Record 7 of Set 6 | kailua
# Processing Record 8 of Set 6 | alta floresta
# Processing Record 9 of Set 6 | te anau
# Processing Record 10 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 6 | moron
# Processing Record 12 of Set 6 | okhotsk
# Processing Record 13 of Set 6 | gopalur
# Processing Record 14 of Set 6 | misratah
# Processing Record 15 of Set 6 | kerrville
# Processing Record 16 of Set 6 | dzhebariki-khaya
# Processing Record 17 of Set 6 | phrai bung
# City not found. Skipping...
# Processing Record 18 of Set 6 | port-gentil
# Processing Record 19 of Set 6 | florianopolis
# Processing Record 20 of Set 6 | delray beach
# Processing Record 21 of Set 6 | ilinskiy
# Processing Record 22 of Set 6 | saryshagan
# City not found. Skipping...
# Processing Record 23 of Set 6 | hokitika
# Processing Record 24 of Set 6 | khani
# Processing Record 25 of Set 6 | hamilton
# Processing Record 26 of Set 6 | barbar
# City not found. Skipping...
# Processing Record 27 of Set 6 | katsuura
# Processing Record 28 of Set 6 | kirkwall
# Processing Record 29 of Set 6 | kavieng
# Processing Record 30 of Set 6 | klaksvik
# Processing Record 31 of Set 6 | lasa
# Processing Record 32 of Set 6 | nyurba
# Processing Record 33 of Set 6 | gandajika
# Processing Record 34 of Set 6 | mangaluru
# Processing Record 35 of Set 6 | salalah
# Processing Record 36 of Set 6 | taltal
# Processing Record 37 of Set 6 | luderitz
# Processing Record 38 of Set 6 | port hardy
# Processing Record 39 of Set 6 | balabac
# Processing Record 40 of Set 6 | oktyabrskiy
# Processing Record 41 of Set 6 | kaitangata
# Processing Record 42 of Set 6 | balkanabat
# Processing Record 43 of Set 6 | prosyana
# City not found. Skipping...
# Processing Record 44 of Set 6 | tahoua
# Processing Record 45 of Set 6 | arraial do cabo
# Processing Record 46 of Set 6 | tezu
# Processing Record 47 of Set 6 | bielsk podlaski
# Processing Record 48 of Set 6 | odweyne
# Processing Record 49 of Set 6 | tampilisan
# Processing Record 50 of Set 6 | buinsk
# Processing Record 1 of Set 7 | ishigaki
# Processing Record 2 of Set 7 | north bend
# Processing Record 3 of Set 7 | el reno
# Processing Record 4 of Set 7 | yeovil
# Processing Record 5 of Set 7 | alugan
# Processing Record 6 of Set 7 | lorengau
# Processing Record 7 of Set 7 | antalaha
# Processing Record 8 of Set 7 | aljezur
# Processing Record 9 of Set 7 | alice springs
# Processing Record 10 of Set 7 | las vegas
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | pasighat
# Processing Record 13 of Set 7 | umm lajj
# Processing Record 14 of Set 7 | plettenberg bay
# Processing Record 15 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 7 | polunochnoye
# Processing Record 17 of Set 7 | adre
# Processing Record 18 of Set 7 | stromness
# Processing Record 19 of Set 7 | taber
# Processing Record 20 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 21 of Set 7 | san cristobal
# Processing Record 22 of Set 7 | yumen
# Processing Record 23 of Set 7 | umm kaddadah
# Processing Record 24 of Set 7 | kargasok
# Processing Record 25 of Set 7 | kawalu
# Processing Record 26 of Set 7 | byron bay
# Processing Record 27 of Set 7 | sisimiut
# Processing Record 28 of Set 7 | bana
# Processing Record 29 of Set 7 | grand centre
# City not found. Skipping...
# Processing Record 30 of Set 7 | vila
# Processing Record 31 of Set 7 | baculin
# Processing Record 32 of Set 7 | cap-aux-meules
# Processing Record 33 of Set 7 | brazzaville
# Processing Record 34 of Set 7 | longyearbyen
# Processing Record 35 of Set 7 | nevelsk
# Processing Record 36 of Set 7 | bathsheba
# Processing Record 37 of Set 7 | rovaniemi
# Processing Record 38 of Set 7 | atagay
# Processing Record 39 of Set 7 | noumea
# Processing Record 40 of Set 7 | svetlogorsk
# Processing Record 41 of Set 7 | dekoa
# City not found. Skipping...
# Processing Record 42 of Set 7 | issia
# Processing Record 43 of Set 7 | komsomolskiy
# Processing Record 44 of Set 7 | yulara
# Processing Record 45 of Set 7 | koslan
# Processing Record 46 of Set 7 | akdepe
# Processing Record 47 of Set 7 | tautira
# Processing Record 48 of Set 7 | kamenka
# Processing Record 49 of Set 7 | upernavik
# Processing Record 50 of Set 7 | port macquarie
# Processing Record 1 of Set 8 | evanston
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | fianga
# City not found. Skipping...
# Processing Record 4 of Set 8 | avera
# Processing Record 5 of Set 8 | sawtell
# Processing Record 6 of Set 8 | parintins
# Processing Record 7 of Set 8 | coihaique
# Processing Record 8 of Set 8 | jacqueville
# Processing Record 9 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 10 of Set 8 | malacatancito
# Processing Record 11 of Set 8 | geraldton
# Processing Record 12 of Set 8 | huarmey
# Processing Record 13 of Set 8 | poso
# Processing Record 14 of Set 8 | toppenish
# Processing Record 15 of Set 8 | bo phloi
# Processing Record 16 of Set 8 | pokaran
# Processing Record 17 of Set 8 | yarqa
# Processing Record 18 of Set 8 | sayyan
# Processing Record 19 of Set 8 | tunduru
# City not found. Skipping...
# Processing Record 20 of Set 8 | galle
# Processing Record 21 of Set 8 | kasongo
# Processing Record 22 of Set 8 | wukari
# Processing Record 23 of Set 8 | laramie
# Processing Record 24 of Set 8 | inirida
# Processing Record 25 of Set 8 | dimovo
# Processing Record 26 of Set 8 | nikolayevskaya
# Processing Record 27 of Set 8 | rundu
# Processing Record 28 of Set 8 | mumford
# Processing Record 29 of Set 8 | thinadhoo
# Processing Record 30 of Set 8 | elizabeth city
# Processing Record 31 of Set 8 | malangali
# Processing Record 32 of Set 8 | praya
# Processing Record 33 of Set 8 | valparaiso
# Processing Record 34 of Set 8 | amqui
# Processing Record 35 of Set 8 | bunia
# Processing Record 36 of Set 8 | hovd
# Processing Record 37 of Set 8 | barstow
# Processing Record 38 of Set 8 | abu samrah
# Processing Record 39 of Set 8 | malanje
# Processing Record 40 of Set 8 | colares
# Processing Record 41 of Set 8 | bandarbeyla
# Processing Record 42 of Set 8 | edmonds
# Processing Record 43 of Set 8 | chiang rai
# Processing Record 44 of Set 8 | presidente medici
# Processing Record 45 of Set 8 | ingham
# Processing Record 46 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 47 of Set 8 | toktogul
# Processing Record 48 of Set 8 | manaure
# Processing Record 49 of Set 8 | chimala
# Processing Record 50 of Set 8 | mega
# Processing Record 1 of Set 9 | placerville
# Processing Record 2 of Set 9 | chinhoyi
# Processing Record 3 of Set 9 | medicine hat
# Processing Record 4 of Set 9 | roald
# Processing Record 5 of Set 9 | najran
# Processing Record 6 of Set 9 | aqtobe
# Processing Record 7 of Set 9 | monrovia
# Processing Record 8 of Set 9 | arvin
# Processing Record 9 of Set 9 | ialibu
# Processing Record 10 of Set 9 | myitkyina
# Processing Record 11 of Set 9 | muros
# Processing Record 12 of Set 9 | the valley
# Processing Record 13 of Set 9 | flinders
# Processing Record 14 of Set 9 | higuey
# City not found. Skipping...
# Processing Record 15 of Set 9 | erdenet
# Processing Record 16 of Set 9 | gboko
# Processing Record 17 of Set 9 | srednekolymsk
# Processing Record 18 of Set 9 | ongandjera
# Processing Record 19 of Set 9 | mainit
# Processing Record 20 of Set 9 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 21 of Set 9 | aksarka
# Processing Record 22 of Set 9 | high level
# Processing Record 23 of Set 9 | trairi
# Processing Record 24 of Set 9 | terrassa
# Processing Record 25 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 9 | dovolnoye
# Processing Record 27 of Set 9 | tommot
# Processing Record 28 of Set 9 | corn island
# Processing Record 29 of Set 9 | chivilcoy
# Processing Record 30 of Set 9 | khash
# Processing Record 31 of Set 9 | nelson bay
# Processing Record 32 of Set 9 | mikuni
# Processing Record 33 of Set 9 | catuday
# Processing Record 34 of Set 9 | asosa
# Processing Record 35 of Set 9 | mulege
# Processing Record 36 of Set 9 | komsomolets
# Processing Record 37 of Set 9 | requena
# Processing Record 38 of Set 9 | sinnamary
# Processing Record 39 of Set 9 | barentsburg
# City not found. Skipping...
# Processing Record 40 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 41 of Set 9 | sabang
# Processing Record 42 of Set 9 | gebre guracha
# Processing Record 43 of Set 9 | prince rupert
# Processing Record 44 of Set 9 | mabaruma
# Processing Record 45 of Set 9 | kieta
# Processing Record 46 of Set 9 | valday
# Processing Record 47 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 48 of Set 9 | lockhart
# Processing Record 49 of Set 9 | talakan
# Processing Record 50 of Set 9 | necochea
# Processing Record 1 of Set 10 | aswan
# Processing Record 2 of Set 10 | shimoda
# Processing Record 3 of Set 10 | gopalpur
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | weligama
# Processing Record 6 of Set 10 | husavik
# Processing Record 7 of Set 10 | abu jubayhah
# City not found. Skipping...
# Processing Record 8 of Set 10 | aklavik
# Processing Record 9 of Set 10 | karratha
# Processing Record 10 of Set 10 | nanortalik
# Processing Record 11 of Set 10 | chifeng
# Processing Record 12 of Set 10 | puerto madryn
# Processing Record 13 of Set 10 | marystown
# Processing Record 14 of Set 10 | stornoway
# Processing Record 15 of Set 10 | mafeteng
# Processing Record 16 of Set 10 | buala
# Processing Record 17 of Set 10 | babanusah
# City not found. Skipping...
# Processing Record 18 of Set 10 | eydhafushi
# Processing Record 19 of Set 10 | vienenburg
# Processing Record 20 of Set 10 | porbandar
# Processing Record 21 of Set 10 | bonavista
# Processing Record 22 of Set 10 | labuhan
# Processing Record 23 of Set 10 | puerto carreno
# Processing Record 24 of Set 10 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 10 | kindu
# Processing Record 26 of Set 10 | muisne
# Processing Record 27 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 28 of Set 10 | praia da vitoria
# Processing Record 29 of Set 10 | mitsamiouli
# Processing Record 30 of Set 10 | nabire
# Processing Record 31 of Set 10 | quatre cocos
# Processing Record 32 of Set 10 | ushtobe
# Processing Record 33 of Set 10 | grenville
# Processing Record 34 of Set 10 | maues
# Processing Record 35 of Set 10 | muli
# Processing Record 36 of Set 10 | richards bay
# Processing Record 37 of Set 10 | hermosillo
# Processing Record 38 of Set 10 | palafrugell
# Processing Record 39 of Set 10 | rocha
# Processing Record 40 of Set 10 | aksu
# Processing Record 41 of Set 10 | kropotkin
# Processing Record 42 of Set 10 | goundam
# Processing Record 43 of Set 10 | baoqing
# Processing Record 44 of Set 10 | lagunas
# Processing Record 45 of Set 10 | kiunga
# Processing Record 46 of Set 10 | den helder
# Processing Record 47 of Set 10 | jinxiang
# Processing Record 48 of Set 10 | hualmay
# Processing Record 49 of Set 10 | san quintin
# Processing Record 50 of Set 10 | mount gambier
# Processing Record 1 of Set 11 | caravelas
# Processing Record 2 of Set 11 | hearst
# Processing Record 3 of Set 11 | karpuninskiy
# City not found. Skipping...
# Processing Record 4 of Set 11 | talara
# Processing Record 5 of Set 11 | ouro fino
# Processing Record 6 of Set 11 | rodrigues alves
# Processing Record 7 of Set 11 | spoleto
# Processing Record 8 of Set 11 | iberia
# Processing Record 9 of Set 11 | novyy svit
# Processing Record 10 of Set 11 | pangoa
# Processing Record 11 of Set 11 | mardin
# Processing Record 12 of Set 11 | valle de allende
# Processing Record 13 of Set 11 | sao joaquim da barra
# Processing Record 14 of Set 11 | samarai
# Processing Record 15 of Set 11 | nuuk
# Processing Record 16 of Set 11 | sao joao da barra
# Processing Record 17 of Set 11 | dukat
# Processing Record 18 of Set 11 | truth or consequences
# Processing Record 19 of Set 11 | roebourne
# Processing Record 20 of Set 11 | saint anthony
# Processing Record 21 of Set 11 | papara
# Processing Record 22 of Set 11 | tomatlan
# Processing Record 23 of Set 11 | kandrian
# Processing Record 24 of Set 11 | college
# Processing Record 25 of Set 11 | aku
# Processing Record 26 of Set 11 | santa barbara
# Processing Record 27 of Set 11 | tahta
# Processing Record 28 of Set 11 | kalmunai
# Processing Record 29 of Set 11 | sept-iles
# Processing Record 30 of Set 11 | moroto
# Processing Record 31 of Set 11 | bollnas
# Processing Record 32 of Set 11 | buique
# Processing Record 33 of Set 11 | todos santos
# Processing Record 34 of Set 11 | kualakapuas
# Processing Record 35 of Set 11 | diego de almagro
# Processing Record 36 of Set 11 | la palma
# Processing Record 37 of Set 11 | redwater
# Processing Record 38 of Set 11 | mareeba
# Processing Record 39 of Set 11 | tenenkou
# Processing Record 40 of Set 11 | hope
# Processing Record 41 of Set 11 | amuntai
# Processing Record 42 of Set 11 | marawi
# Processing Record 43 of Set 11 | port keats
# Processing Record 44 of Set 11 | faya
# Processing Record 45 of Set 11 | saint george
# Processing Record 46 of Set 11 | beloha
# Processing Record 47 of Set 11 | iguape
# Processing Record 48 of Set 11 | whyalla
# Processing Record 49 of Set 11 | road town
# Processing Record 50 of Set 11 | arandis
# Processing Record 1 of Set 12 | panayakan
# City not found. Skipping...
# Processing Record 2 of Set 12 | pacific grove
# Processing Record 3 of Set 12 | yamada
# Processing Record 4 of Set 12 | nizhniy tsasuchey
# Processing Record 5 of Set 12 | dagana
# Processing Record 6 of Set 12 | bilibino
# Processing Record 7 of Set 12 | rancho palos verdes
# Processing Record 8 of Set 12 | cangucu
# Processing Record 9 of Set 12 | hurghada
# Processing Record 10 of Set 12 | anadyr
# Processing Record 11 of Set 12 | ahuimanu
# Processing Record 12 of Set 12 | itupiranga
# Processing Record 13 of Set 12 | lumberton
# Processing Record 14 of Set 12 | xique-xique
# Processing Record 15 of Set 12 | ciudad bolivar
# Processing Record 16 of Set 12 | ormara
# Processing Record 17 of Set 12 | ulaangom
# Processing Record 18 of Set 12 | barcelos
# Processing Record 19 of Set 12 | srandakan
# Processing Record 20 of Set 12 | assiniboia
# Processing Record 21 of Set 12 | baruun-urt
# Processing Record 22 of Set 12 | oktyabrskoye
# Processing Record 23 of Set 12 | san pedro
# Processing Record 24 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 25 of Set 12 | souillac
# Processing Record 26 of Set 12 | henties bay
# Processing Record 27 of Set 12 | cascais
# Processing Record 28 of Set 12 | popondetta
# Processing Record 29 of Set 12 | fuyang
# Processing Record 30 of Set 12 | turukhansk
# Processing Record 31 of Set 12 | kenai
# Processing Record 32 of Set 12 | jinchang
# Processing Record 33 of Set 12 | yaan
# Processing Record 34 of Set 12 | mitchell
# Processing Record 35 of Set 12 | amahai
# Processing Record 36 of Set 12 | arles
# Processing Record 37 of Set 12 | hatillo
# Processing Record 38 of Set 12 | bambanglipuro
# Processing Record 39 of Set 12 | peniche
# Processing Record 40 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 41 of Set 12 | san vicente
# Processing Record 42 of Set 12 | shache
# Processing Record 43 of Set 12 | samana
# Processing Record 44 of Set 12 | ginda
# Processing Record 45 of Set 12 | mayo
# Processing Record 46 of Set 12 | kapoeta
# Processing Record 47 of Set 12 | tromso
# Processing Record 48 of Set 12 | umzimvubu
# City not found. Skipping...
# Processing Record 49 of Set 12 | emba
# Processing Record 50 of Set 12 | inhambane
# Processing Record 1 of Set 13 | ust-omchug
# Processing Record 2 of Set 13 | ouallam
# Processing Record 3 of Set 13 | shizilu
# Processing Record 4 of Set 13 | slave lake
# Processing Record 5 of Set 13 | borgustanskaya
# Processing Record 6 of Set 13 | harper
# Processing Record 7 of Set 13 | macatuba
# Processing Record 8 of Set 13 | churapcha
# Processing Record 9 of Set 13 | kerikeri
# Processing Record 10 of Set 13 | taft
# Processing Record 11 of Set 13 | vilshofen
# Processing Record 12 of Set 13 | houma
# Processing Record 13 of Set 13 | inuvik
# Processing Record 14 of Set 13 | ocean city
# Processing Record 15 of Set 13 | homer
# Processing Record 16 of Set 13 | impfondo
# Processing Record 17 of Set 13 | rosarno
# Processing Record 18 of Set 13 | aurich
# Processing Record 19 of Set 13 | saint-pierre
# Processing Record 20 of Set 13 | vestmannaeyjar
# Processing Record 21 of Set 13 | kachikau
# City not found. Skipping...
# Processing Record 22 of Set 13 | caboolture
# Processing Record 23 of Set 13 | alsfeld
# Processing Record 24 of Set 13 | naryan-mar
# Processing Record 25 of Set 13 | shenzhen
# Processing Record 26 of Set 13 | rantepao
# Processing Record 27 of Set 13 | miri
# Processing Record 28 of Set 13 | kushiro
# Processing Record 29 of Set 13 | dong hoi
# Processing Record 30 of Set 13 | dudinka
# Processing Record 31 of Set 13 | tagusao
# Processing Record 32 of Set 13 | karlskrona
# Processing Record 33 of Set 13 | urdoma
# Processing Record 34 of Set 13 | swellendam
# Processing Record 35 of Set 13 | rybnaya sloboda
# Processing Record 36 of Set 13 | kaeo
# Processing Record 37 of Set 13 | lima
# Processing Record 38 of Set 13 | elk river
# Processing Record 39 of Set 13 | riverton
# Processing Record 40 of Set 13 | yoichi
# Processing Record 41 of Set 13 | tessalit
# Processing Record 42 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 43 of Set 13 | tari
# Processing Record 44 of Set 13 | bandipur
# Processing Record 45 of Set 13 | helong
# Processing Record 46 of Set 13 | san ramon
# Processing Record 47 of Set 13 | skibbereen
# Processing Record 48 of Set 13 | chongqing
# Processing Record 49 of Set 13 | los llanos de aridane
# Processing Record 50 of Set 13 | juneau
# Processing Record 1 of Set 14 | mattru
# Processing Record 2 of Set 14 | baghdad
# Processing Record 3 of Set 14 | abapo
# Processing Record 4 of Set 14 | iskateley
# Processing Record 5 of Set 14 | pyapon
# Processing Record 6 of Set 14 | atar
# Processing Record 7 of Set 14 | mehamn
# Processing Record 8 of Set 14 | burnie
# Processing Record 9 of Set 14 | labutta
# City not found. Skipping...
# Processing Record 10 of Set 14 | boa vista
# Processing Record 11 of Set 14 | tsumeb
# Processing Record 12 of Set 14 | liuhe
# Processing Record 13 of Set 14 | taylorville
# Processing Record 14 of Set 14 | itoigawa
# Processing Record 15 of Set 14 | san juan
# Processing Record 16 of Set 14 | guarapari
# Processing Record 17 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 18 of Set 14 | blackwater
# Processing Record 19 of Set 14 | polyarnyy
# Processing Record 20 of Set 14 | barao de melgaco
# Processing Record 21 of Set 14 | nemuro
# Processing Record 22 of Set 14 | westport
# Processing Record 23 of Set 14 | sena madureira
# Processing Record 24 of Set 14 | big bend
# Processing Record 25 of Set 14 | gulshat
# City not found. Skipping...
# Processing Record 26 of Set 14 | jumla
# Processing Record 27 of Set 14 | leh
# Processing Record 28 of Set 14 | menzelinsk
# Processing Record 29 of Set 14 | piste
# Processing Record 30 of Set 14 | sol-iletsk
# Processing Record 31 of Set 14 | shido
# Processing Record 32 of Set 14 | hay river
# Processing Record 33 of Set 14 | terney
# Processing Record 34 of Set 14 | zhetybay
# City not found. Skipping...
# Processing Record 35 of Set 14 | fukue
# Processing Record 36 of Set 14 | rio cuarto
# Processing Record 37 of Set 14 | ayagoz
# Processing Record 38 of Set 14 | staraya poltavka
# Processing Record 39 of Set 14 | ajdabiya
# Processing Record 40 of Set 14 | namatanai
# Processing Record 41 of Set 14 | moose factory
# Processing Record 42 of Set 14 | port hedland
# Processing Record 43 of Set 14 | klyuchi
# Processing Record 44 of Set 14 | kurilsk
# Processing Record 45 of Set 14 | ardakan
# Processing Record 46 of Set 14 | acari
# Processing Record 47 of Set 14 | banon
# Processing Record 48 of Set 14 | matagami
# Processing Record 49 of Set 14 | formosa
# Processing Record 50 of Set 14 | eucaliptus
# Processing Record 1 of Set 15 | zhangye
# Processing Record 2 of Set 15 | gilgit
# Processing Record 3 of Set 15 | filingue
# Processing Record 4 of Set 15 | koindu
# Processing Record 5 of Set 15 | itoman
# Processing Record 6 of Set 15 | solnechnyy
# Processing Record 7 of Set 15 | havelock
# Processing Record 8 of Set 15 | zaoyang
# Processing Record 9 of Set 15 | natal
# Processing Record 10 of Set 15 | syasstroy
# Processing Record 11 of Set 15 | acapulco
# Processing Record 12 of Set 15 | ylojarvi
# Processing Record 13 of Set 15 | severo-yeniseyskiy
# Processing Record 14 of Set 15 | parsabad
# Processing Record 15 of Set 15 | alekseyevsk
# Processing Record 16 of Set 15 | nouadhibou
# Processing Record 17 of Set 15 | calvinia
# Processing Record 18 of Set 15 | amudat
# Processing Record 19 of Set 15 | bonito
# Processing Record 20 of Set 15 | hirtshals
# Processing Record 21 of Set 15 | asaba
# Processing Record 22 of Set 15 | onokhoy
# Processing Record 23 of Set 15 | borger
# Processing Record 24 of Set 15 | kushima
# Processing Record 25 of Set 15 | kenora
# Processing Record 26 of Set 15 | dubenskiy
# City not found. Skipping...
# Processing Record 27 of Set 15 | palmer
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 673

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Sur  22.5667   59.5289     79.66        43          99
# 1  Severo-Kurilsk  50.6789  156.1250     42.28        71         100
# 2       Carnarvon -24.8667  113.6333     65.50        60          46
# 3        Balkhash  46.8440   74.9804     53.01        58         100
# 4    Punta Arenas -53.1500  -70.9167     60.91        33           0
# 5           Dekar -21.5333   21.9333     71.80        47         100
# 6      Bredasdorp -34.5322   20.0403     62.71        87          19
# 7         Ushuaia -54.8000  -68.3000     49.66        40           0
# 8         Mataura -46.1927  168.8643     48.58        77          75
# 9        Ust-Nera  64.5667  143.2000      0.25        99          87
#
#    Wind Speed Country Current Description
# 0        7.11      OM     overcast clouds
# 1        9.46      RU     overcast clouds
# 2       21.43      AU    scattered clouds
# 3       10.02      KZ     overcast clouds
# 4       25.32      CL           clear sky
# 5       10.02      BW     overcast clouds
# 6        7.43      ZA          few clouds
# 7        4.61      AR           clear sky
# 8        3.98      NZ       broken clouds
# 9        3.62      RU     overcast clouds

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Country', 'Current Description'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ['City', 'Country', 'Lat', 'Lng', 'Max Temp','Humidity', 'Cloudiness', 'Wind Speed', 'Current Description']



# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0             Sur      OM  22.5667   59.5289     79.66        43          99
# 1  Severo-Kurilsk      RU  50.6789  156.1250     42.28        71         100
# 2       Carnarvon      AU -24.8667  113.6333     65.50        60          46
# 3        Balkhash      KZ  46.8440   74.9804     53.01        58         100
# 4    Punta Arenas      CL -53.1500  -70.9167     60.91        33           0
# 5           Dekar      BW -21.5333   21.9333     71.80        47         100
# 6      Bredasdorp      ZA -34.5322   20.0403     62.71        87          19
# 7         Ushuaia      AR -54.8000  -68.3000     49.66        40           0
# 8         Mataura      NZ -46.1927  168.8643     48.58        77          75
# 9        Ust-Nera      RU  64.5667  143.2000      0.25        99          87
#
#    Wind Speed Current Description
# 0        7.11     overcast clouds
# 1        9.46     overcast clouds
# 2       21.43    scattered clouds
# 3       10.02     overcast clouds
# 4       25.32           clear sky
# 5       10.02     overcast clouds
# 6        7.43          few clouds
# 7        4.61           clear sky
# 8        3.98       broken clouds
# 9        3.62     overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = 'WeatherPy_Database.csv'

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
